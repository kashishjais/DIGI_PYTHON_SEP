# %%
from PIL import Image

# %%
doraemon=Image.open('img.jpg')
doraemon
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1280x1500 at 0x29A8F4E7220>

# %%
doraemon.size
# Out:
# (1280, 1500)

# %%
doraemon.format
# Out:
# 'JPEG'

# %%
doraemon.mode
# Out:
# 'RGB'

# %%
doraemon.convert('L')
# Out:
# <PIL.Image.Image image mode=L size=1280x1500 at 0x29A8F5378B0>

# %%
b_w=doraemon.convert('1')
b_w
# Out:
# <PIL.Image.Image image mode=1 size=1280x1500 at 0x29A8F43AD10>

# %%
b_w.save('new_img.jpg', 'JPEG')

# %%
crop_box=(300,100,1000,900)

# %%
doraemon.crop(crop_box)
# Out:
# <PIL.Image.Image image mode=RGB size=700x800 at 0x18164297FA0>
